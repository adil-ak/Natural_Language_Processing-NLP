# %%
import pandas as pd
df_true=pd.read_csv("True.csv")
df_fake=pd.read_csv("Fake.csv")

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  target
# 0  December 31, 2017       1
# 1  December 31, 2017       1
# 2  December 30, 2017       1
# 3  December 29, 2017       1
# 4  December 25, 2017       1

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  target
# 0  December 31, 2017        0
# 1  December 29, 2017        0
# 2  December 31, 2017        0
# 3  December 30, 2017        0
# 4  December 29, 2017        0

# %%
df=pd.concat([df_true,df_fake],ignore_index=True)

# %%
df
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 44893  McPain: John McCain Furious That Iran Treated ...
# 44894  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 44895  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 44896  How to Blow $700 Million: Al Jazeera America F...
# 44897  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %%
df.drop(['subject','date','title'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                                 text  target
# 0  WASHINGTON (Reuters) - The head of a conservat...       0
# 1  WASHINGTON (Reuters) - Transgender people will...       0
# 2  WASHINGTON (Reuters) - The special counsel inv...       0
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...       0
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...       0

# %%
df.tail()
# Out:
#                                                     text  target
# 44893  21st Century Wire says As 21WIRE reported earl...       1
# 44894  21st Century Wire says It s a familiar theme. ...       1
# 44895  Patrick Henningsen  21st Century WireRemember ...       1
# 44896  21st Century Wire says Al Jazeera America will...       1
# 44897  21st Century Wire says As 21WIRE predicted in ...       1

# %%
df.isnull().sum()
# Out:
# text      0
# target    0
# dtype: int64

# %% [markdown]
# #Create function to do Normalization

# %%
# import string
# punc=string.punctuation
# def remove_punc_and_lower(text):
#   flag=str.maketrans('','',punc)
#   removed=text.translate(flag)
#   new=removed.lower()
#   return new

# %%
import re
def remove_punc_and_lower(text):
  text=re.sub(r'[^a-zA-Z]',' ',text)
  new=text.lower()
  return new

# %%
txt="Hello,my dear, boy"
t=remove_punc_and_lower(txt)
t
# Out:
# 'hello my dear  boy'

# %%
df['text']=df['text'].apply(remove_punc_and_lower)
df
# Out:
#                                                     text  target
# 0      washington  reuters    the head of a conservat...       0
# 1      washington  reuters    transgender people will...       0
# 2      washington  reuters    the special counsel inv...       0
# 3      washington  reuters    trump campaign adviser ...       0
# 4      seattle washington  reuters    president donal...       0
# ...                                                  ...     ...
# 44893    st century wire says as   wire reported earl...       1
# 44894    st century wire says it s a familiar theme  ...       1
# 44895  patrick henningsen    st century wireremember ...       1
# 44896    st century wire says al jazeera america will...       1
# 44897    st century wire says as   wire predicted in ...       1
#
# [44898 rows x 2 columns]

# %% [markdown]
# #Remove Stopwords

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
sw=stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# #Stop Words

# %%
def remove_stopwords(text):
  sw=stopwords.words('english')
  words=nltk.word_tokenize(text)
  removed=[]
  for word in words:
    if word not in sw:
      removed.append(word)
  return ' '.join(removed)

# %% [markdown]
# #Stemming

# %%
from nltk.stem.porter import PorterStemmer
def stemming(text):
  stemmer=PorterStemmer()
  words=nltk.word_tokenize(text)
  stemmed=[]
  for word in words:
    stemmed.append(stemmer.stem(word))
  return ' '.join(stemmed)

# %%
df['text']=df['text'].apply(remove_stopwords)
df['text']=df['text'].apply(stemming)

# %%
df.tail()
# Out:
#                                                     text  target
# 44893  st centuri wire say wire report earlier week u...       1
# 44894  st centuri wire say familiar theme whenev disp...       1
# 44895  patrick henningsen st centuri wirerememb obama...       1
# 44896  st centuri wire say al jazeera america go hist...       1
# 44897  st centuri wire say wire predict new year look...       1

# %% [markdown]
# #Training ,Testing Split

# %%
x=df['text']
y=df['target']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tf=TfidfVectorizer()
x_train=tf.fit_transform(x_train)
x_test=tf.transform(x_test)

# %% [markdown]
# #Naive Bayes Model

# %%
import sklearn.model_selection as model_selection
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
nb=MultinomialNB()
model=nb.fit(x_train,y_train)

# %%
accuracy=model.score(x_test,y_test)
accuracy*100
# Out:
# 93.50779510022271
